# %%
#IMPORT DEPENDENCY
import pandas as pd
import matplotlib as plt

# %%
#IMPORT CSV
soccer_data_load = "soccer_data_V1.csv"

# %%
#LOAD SOCCER DATA INTO A DATAFRAME

soccer_data_df = pd.read_csv(soccer_data_load, encoding = 'unicode_escape')

# %%
soccer_data_df.head()
# Out:
#                  team_name           common_name     season  country  \
# 0               Arsenal FC               Arsenal  2020/2021  England
# 1     Tottenham Hotspur FC     Tottenham Hotspur  2020/2021  England
# 2       Manchester City FC       Manchester City  2020/2021  England
# 3        Leicester City FC        Leicester City  2020/2021  England
# 4  West Bromwich Albion FC  West Bromwich Albion  2020/2021  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              13                    7                    6
# 1              13                    6                    7
# 2              12                    6                    6
# 3              13                    7                    6
# 4              13                    6                    7
#
#    suspended_matches  wins  wins_home  ...  goals_conceded_min_51_to_60  \
# 0                  0     4          2  ...                            0
# ...

# %%
soccer_data_df.plot(x='points_per_game',y='goals_scored',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='goals_conceded',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='clean_sheets_away',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='clean_sheets',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='first_team_to_score_percentage',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='goals_scored_per_match',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='cards_per_match',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='goals_conceded_min_81_to_90',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='goals_scored_min_81_to_90',kind='scatter')

# %%
soccer_data_df.plot(x='league_position',y='points_per_game',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='average_possession',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='average_possession_home',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='average_possession_away',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='shots',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='shots_on_target',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='fouls',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='leading_at_half_time',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='clean_sheet_percentage',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='goals_scored_min_21_to_30',kind='scatter')

# %%
soccer_data_df.plot(x='points_per_game',y='xg_for_avg_overall',kind='scatter')
