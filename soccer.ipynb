# %%
#IMPORT DEPENDENCY
import pandas as pd
import matplotlib as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import datasets

# %%
#IMPORT CSV
soccer_data_dom_load = "soccer_data_domesitc_v1.csv"
soccer_data_eur_load = "soccer_data_europe.csv"

# %%
#LOAD SOCCER DATA INTO A DATAFRAME

soccer_data_dom_df = pd.read_csv(soccer_data_dom_load, encoding = 'unicode_escape')
soccer_data_eur_df = pd.read_csv(soccer_data_eur_load, encoding = 'unicode_escape')

# %%
soccer_data_dom_df.head()
# Out:
#                  team_name           common_name     season  country  \
# 0               Arsenal FC               Arsenal  2020/2021  England
# 1     Tottenham Hotspur FC     Tottenham Hotspur  2020/2021  England
# 2       Manchester City FC       Manchester City  2020/2021  England
# 3        Leicester City FC        Leicester City  2020/2021  England
# 4  West Bromwich Albion FC  West Bromwich Albion  2020/2021  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              13                    7                    6
# 1              13                    6                    7
# 2              12                    6                    6
# 3              13                    7                    6
# 4              13                    6                    7
#
#    suspended_matches  wins  wins_home  ...  goals_conceded_min_51_to_60  \
# 0                  0     4          2  ...                            0
# ...

# %%
soccer_data_eur_df.head()
# Out:
#                   team_name         common_name     season  country  \
# 0  BVB 09 Borussia Dortmund   Borussia Dortmund  2011/2012  Germany
# 1        FC Bayern MÃ¼nchen     Bayern MÃ¼nchen  2011/2012  Germany
# 2       Bayer 04 Leverkusen    Bayer Leverkusen  2011/2012  Germany
# 3        Olympique Lyonnais  Olympique Lyonnais  2011/2012   France
# 4                Arsenal FC             Arsenal  2011/2012  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0               6                    3                    3
# 1              15                    8                    7
# 2               8                    4                    4
# 3              10                    5                    5
# 4              10                    5                    5
#
#    suspended_matches  wins  wins_home  ...  goals_conceded_min_51_to_60  \
# 0                  0     1          1  ...                            0
# ...

# %%
goals_scored = soccer_data_dom_df.plot.scatter(x='performance_rank',y='goals_scored_per_match')

# %%
avg_poss= soccer_data_dom_df.plot.scatter(x='performance_rank',y='wins_home')

# %%
clean_sheets = soccer_data_dom_df.plot.scatter(x='performance_rank',y='first_team_to_score_percentage')

# %%
shots_target = soccer_data_dom_df.plot.scatter(x='performance_rank',y='leading_at_half_time_percentage')

# %%
firsttoscore = soccer_data_dom_df.plot.scatter(x='performance_rank',y='fts_percentage')

# %%
xg_for = soccer_data_dom_df.plot.scatter(x='performance_rank',y='wins_away')

# %%
xg_against = soccer_data_dom_df.plot.scatter(x='performance_rank',y='losing_at_half_time_percentage')

# %%
goals_conceded = soccer_data_dom_df.plot.scatter(x='performance_rank',y='goals_conceded_per_match')

# %%
goals_conceded = soccer_data_dom_df.plot.scatter(x='performance_rank',y='fts_half_time_percentage')

# %%
test = soccer_data_dom_df.plot.scatter(x='performance_rank',y='clean_sheet_percentage')

# %%
test = soccer_data_dom_df.plot.scatter(x='performance_rank',y='corners_per_match')

# %%
test = soccer_data_dom_df.plot.scatter(x='performance_rank',y='shots_on_target')
