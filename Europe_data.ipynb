# %%
#IMPORT DEPENDENCY
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
#IMPORT CSV
soccer_data_load = "soccer_data_europe.csv"
soccer_data_df = pd.read_csv(soccer_data_load, encoding = 'unicode_escape')

# %%
soccer_data_df
# Out:
#                            team_name          common_name     season  country  \
# 0           BVB 09 Borussia Dortmund    Borussia Dortmund  2011/2012  Germany
# 1                 FC Bayern MÃ¼nchen      Bayern MÃ¼nchen  2011/2012  Germany
# 2                Bayer 04 Leverkusen     Bayer Leverkusen  2011/2012  Germany
# 3                 Olympique Lyonnais   Olympique Lyonnais  2011/2012   France
# 4                         Arsenal FC              Arsenal  2011/2012  England
# ..                               ...                  ...        ...      ...
# 210           Olympique de Marseille  Olympique Marseille  2010/2011   France
# 211                         AC Milan             AC Milan  2010/2011    Italy
# 212                     UC Sampdoria            Sampdoria  2010/2011    Italy
# 213         FC Internazionale Milano          Inter Milan  2010/2011    Italy
# 214  Association Jeunesse Auxerroise              Auxerre  2010/2011   France
#
# ...

# %%
soccer_df = soccer_data_df.drop(["team_name", "suspended_matches", "draws_home", "draws_away", "losses_home", 
                                 "losses_away", "points_per_game_home", "points_per_game_away", 
                                 "league_position_home", "league_position_away", "goal_difference", 
                                 "total_goal_count", "total_goal_count_home", "total_goal_count_away", 
                                 "goals_conceded_home", "goals_conceded_away", "goal_difference_home", 
                                 "goal_difference_away", "minutes_per_goal_scored", "minutes_per_goal_scored_home"
                                 , "minutes_per_goal_scored_away", "minutes_per_goal_conceded", 
                                 "minutes_per_goal_conceded_home", "minutes_per_goal_conceded_away", 
                                 "clean_sheets", "clean_sheets_home", "clean_sheets_away", "btts_count", 
                                 "btts_count_home", "btts_count_away", "fts_count", "fts_count_home", 
                                 "fts_count_away", "first_team_to_score_count", "first_team_to_score_count_home",
                                 "first_team_to_score_count_away", "corners_total_home", 
                                 "corners_total_away", "cards_total", "cards_total_home", "cards_total_away", 
                                 "average_possession_home", "average_possession_away", 
                                 "shots_home", "shots_away", "shots_on_target_home", 
                                 "shots_on_target_away", "shots_off_target", "shots_off_target_home", 
                                 "shots_off_target_away", "fouls_home", "fouls_away", "goals_scored_half_time",
                                 "goals_scored_half_time_home", "goals_scored_half_time_away", 
                                 "goals_conceded_half_time", "goals_conceded_half_time_home", 
                                 "goals_conceded_half_time_away", "goal_difference_half_time", 
                                 "goal_difference_half_time_home", "goal_difference_half_time_away",
                                 "leading_at_half_time", "leading_at_half_time_home", "leading_at_half_time_away",
                                 "draw_at_half_time", "draw_at_half_time_home", "draw_at_half_time_away", 
                                 "losing_at_half_time", "losing_at_half_time_home", "losing_at_half_time_away", 
                                 "points_per_game_half_time_away", "average_total_goals_per_match",
                                 "average_total_goals_per_match_home","average_total_goals_per_match_away", 
                                 "goals_scored_per_match_home", "goals_scored_per_match_away", 
                                 "goals_conceded_per_match_home", "goals_conceded_per_match_away", 
                                 "total_goals_per_match_half_time", "total_goals_per_match_half_time_home",
                                 "total_goals_per_match_half_time_away", "goals_scored_per_match_half_time",
                                 "goals_scored_per_match_half_time_home", "goals_scored_per_match_half_time_away",
                                 "goals_conceded_per_match_half_time_home",
                                 "goals_conceded_per_match_half_time_away", "win_percentage", 
                                 "win_percentage_home", "win_percentage_away", "home_advantage_percentage",
                                 "clean_sheet_percentage_home", "clean_sheet_percentage_away",
                                 "btts_percentage", "btts_percentage_home", "btts_percentage_away", 
                                 "fts_percentage_home", "fts_percentage_away", 
                                 "first_team_to_score_percentage_home", 
                                 "first_team_to_score_percentage_away", "clean_sheet_half_time", 
                                 "clean_sheet_half_time_home", "clean_sheet_half_time_away",
                                 "clean_sheet_half_time_percentage",
                                 "clean_sheet_half_time_percentage_away", "fts_half_time", "fts_half_time_home",
                                 "fts_half_time_away", "btts_half_time", "btts_half_time_home",
                                 "btts_half_time_away", "btts_half_time_percentage_home",
                                 "btts_half_time_percentage_away","leading_at_half_time_percentage_away",
                                 "draw_at_half_time_percentage", "draw_at_half_time_percentage_home", 
                                 "draw_at_half_time_percentage_away", 
                                 "losing_at_half_time_percentage_home", "losing_at_half_time_percentage_away",
                                 "corners_per_match_home", "corners_per_match_away", "cards_per_match_home",
                                 "cards_per_match_away", "xg_for_avg_overall", "xg_for_avg_home",
                                 "xg_for_avg_away", "xg_against_avg_overall", "xg_against_avg_home",
                                 "xg_against_avg_away", "prediction_risk", "goals_scored_min_0_to_10",
                                 "goals_scored_min_11_to_20", "goals_scored_min_21_to_30", 
                                 "goals_scored_min_31_to_40", "goals_scored_min_41_to_50", 
                                 "goals_scored_min_51_to_60", "goals_scored_min_61_to_70", 
                                 "goals_scored_min_71_to_80", "goals_scored_min_81_to_90",
                                 "goals_conceded_min_0_to_10", "goals_conceded_min_11_to_20",
                                 "goals_conceded_min_21_to_30", "goals_conceded_min_31_to_40",
                                 "goals_conceded_min_41_to_50", "goals_conceded_min_51_to_60",
                                 "goals_conceded_min_61_to_70", "goals_conceded_min_71_to_80",
                                 "goals_conceded_min_81_to_90", "draw_percentage_overall",
                                 "draw_percentage_home", "draw_percentage_away", "loss_percentage_ovearll",
                                 "loss_percentage_home", "loss_percentage_away", "matches_played_home", "matches_played_away",
                                 "goals_scored_home", "goals_scored_away", "points_per_game_half_time_home", 
                                 "fts_half_time_percentage_home", "fts_half_time_percentage_away", "leading_at_half_time_percentage_home",
                                 "btts_half_time_percentage"], axis=1)
print(soccer_df.shape)
soccer_df.head(5)
# Out:
# (215, 32)
#           common_name     season  country  matches_played  wins  wins_home  \
# 0   Borussia Dortmund  2011/2012  Germany               6     1          1
# 1     Bayern MÃ¼nchen  2011/2012  Germany              15    10          7
# 2    Bayer Leverkusen  2011/2012  Germany               8     3          3
# 3  Olympique Lyonnais  2011/2012   France              10     4          3
# 4             Arsenal  2011/2012  England              10     6          4
#
#    wins_away  draws  losses  points_per_game  ...  \
# 0          0      1       4             0.67  ...
# 1          3      2       3             2.13  ...
# 2          0      1       4             1.25  ...
# 3          1      3       3             1.50  ...
# 4          2      2       2             2.00  ...
#
#    goals_conceded_per_match_half_time  clean_sheet_percentage  fts_percentage  \
# 0                                0.83                      17              17
# ...

# %%
soccer_df = soccer_df.rename(columns={"common_name": "Team", "season": "Season", "country": "Country",
                                     "matches_played": "Matches Played", "wins": "Wins", "wins_home": "Home Wins",
                                     "wins_away": "Away Wins", "draws": "Draws", "losses": "Loses",
                                     "points_per_game": "Point Per Game", "league_position": "League Position",
                                     "performance_rank": "Rank", "goals_scored": "Goals Scored",
                                     "goals_conceded": "Goals Conceded", "corners_total": "Total Corners",
                                     "average_possession": "Average Possession", "shots": "Shots", 
                                     "shots_on_target": "Shots on Target", "fouls": "Fouls",
                                     "points_per_game_half_time": "Points Per Game Half Time", 
                                     "goals_scored_per_match": "Goals Per Match", "goals_conceded_per_match":
                                     "Goals Conceded Per Match", "goals_conceded_per_match_half_time": 
                                     "Goals Conceded At Half Time", "clean_sheet_percentage": "Clean Sheet Percentage",
                                     "fts_percentage": "Failed to Score Percentage", "first_team_to_score_percentage":
                                     "First Team to Score Percentage", "clean_sheet_half_time_percentage_home":
                                     "Clean Sheet At Half Time Home", "fts_half_time_percentage":
                                     "Failed to Score at Half Time", "leading_at_half_time_percentage":
                                     "Leading at Half Time", "losing_at_half_time_percentage": "Losing at Half Time",
                                     "corners_per_match": "Corners Per Match", "cards_per_match": "Cards Per Match"})
soccer_df.head()
# Out:
#                  Team     Season  Country  Matches Played  Wins  Home Wins  \
# 0   Borussia Dortmund  2011/2012  Germany               6     1          1
# 1     Bayern MÃ¼nchen  2011/2012  Germany              15    10          7
# 2    Bayer Leverkusen  2011/2012  Germany               8     3          3
# 3  Olympique Lyonnais  2011/2012   France              10     4          3
# 4             Arsenal  2011/2012  England              10     6          4
#
#    Away Wins  Draws  Loses  Point Per Game  ...  Goals Conceded At Half Time  \
# 0          0      1      4            0.67  ...                         0.83
# 1          3      2      3            2.13  ...                         0.33
# 2          0      1      4            1.25  ...                         0.75
# 3          1      3      3            1.50  ...                         0.50
# 4          2      2      2            2.00  ...                         0.60
#
# ...

# %%
list(soccer_df.columns.values)
# Out:
# ['Team',
#  'Season',
#  'Country',
#  'Matches Played',
#  'Wins',
#  'Home Wins',
#  'Away Wins',
#  'Draws',
#  'Loses',
#  'Point Per Game',
#  'League Position',
#  'Rank',
#  'Goals Scored',
#  'Goals Conceded',
#  'Total Corners',
#  'Average Possession',
#  'Shots',
#  'Shots on Target',
#  'Fouls',
#  'Points Per Game Half Time',
#  'Goals Per Match',
#  'Goals Conceded Per Match',
#  'Goals Conceded At Half Time',
#  'Clean Sheet Percentage',
#  'Failed to Score Percentage',
#  'First Team to Score Percentage',
#  'Clean Sheet At Half Time Home',
#  'Failed to Score at Half Time',
#  'Leading at Half Time',
#  'Losing at Half Time',
#  'Corners Per Match',
#  'Cards Per Match']

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/soccer_project"

# %%
engine = create_engine(db_string)

# %%
soccer_df.to_sql(name='champion_data', con=engine)
