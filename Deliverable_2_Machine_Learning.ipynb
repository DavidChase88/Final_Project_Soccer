# %%
#IMPORT DEPENDENCY
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
#LOAD SOCCER DATA INTO A DATAFRAME
soccer_data_load = "C:/Users/davec/Desktop/Class/20_Final_Project/soccer_data_V1.csv"
soccer_data_df = pd.read_csv(soccer_data_load, encoding = 'unicode_escape')
soccer_data_df.head(10)
# Out:
#                  team_name           common_name     season  country  \
# 0               Arsenal FC               Arsenal  2020/2021  England
# 1     Tottenham Hotspur FC     Tottenham Hotspur  2020/2021  England
# 2       Manchester City FC       Manchester City  2020/2021  England
# 3        Leicester City FC        Leicester City  2020/2021  England
# 4  West Bromwich Albion FC  West Bromwich Albion  2020/2021  England
# 5        Crystal Palace FC        Crystal Palace  2020/2021  England
# 6               Everton FC               Everton  2020/2021  England
# 7               Burnley FC               Burnley  2020/2021  England
# 8           Southampton FC           Southampton  2020/2021  England
# 9     Manchester United FC     Manchester United  2020/2021  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              13                    7                    6
# 1              13                    6                    7
# ...

# %%
# Drop the null columns where all values are null
soccer_data_null_columns_df = soccer_data_df.dropna(axis='columns', how='all')
soccer_data_null_columns_df
# Out:
#                             team_name           common_name     season  \
# 0                          Arsenal FC               Arsenal  2020/2021
# 1                Tottenham Hotspur FC     Tottenham Hotspur  2020/2021
# 2                  Manchester City FC       Manchester City  2020/2021
# 3                   Leicester City FC        Leicester City  2020/2021
# 4             West Bromwich Albion FC  West Bromwich Albion  2020/2021
# ...                               ...                   ...        ...
# 1053           Getafe Club de F?§tbol             Getafe CF  2020/2021
# 1054                         Elche CF              Elche CF  2020/2021
# 1055  Real Valladolid Club de F?§tbol       Real Valladolid  2020/2021
# 1056                        SD Huesca             SD Huesca  2020/2021
# 1057                        C?­diz CF                C?­diz  2020/2021
#
#       country  matches_played  matches_played_home  matches_played_away  \
# ...

# %%
# Drop the null rows
df_null = soccer_data_df.dropna()
df_null

# No columns or rows were dropped so we can use our original data.
# Out:
#                             team_name           common_name     season  \
# 0                          Arsenal FC               Arsenal  2020/2021
# 1                Tottenham Hotspur FC     Tottenham Hotspur  2020/2021
# 2                  Manchester City FC       Manchester City  2020/2021
# 3                   Leicester City FC        Leicester City  2020/2021
# 4             West Bromwich Albion FC  West Bromwich Albion  2020/2021
# ...                               ...                   ...        ...
# 1053           Getafe Club de F?§tbol             Getafe CF  2020/2021
# 1054                         Elche CF              Elche CF  2020/2021
# 1055  Real Valladolid Club de F?§tbol       Real Valladolid  2020/2021
# 1056                        SD Huesca             SD Huesca  2020/2021
# 1057                        C?­diz CF                C?­diz  2020/2021
#
#       country  matches_played  matches_played_home  matches_played_away  \
# ...

# %%
soccer_data_df['Champion'] = np.where(soccer_data_df['league_position'] == 1, "Champion", "Not")
soccer_data_df[['team_name','season','Champion']].head(200)
# Out:
#                       team_name     season Champion
# 0                    Arsenal FC  2020/2021      Not
# 1          Tottenham Hotspur FC  2020/2021      Not
# 2            Manchester City FC  2020/2021      Not
# 3             Leicester City FC  2020/2021      Not
# 4       West Bromwich Albion FC  2020/2021      Not
# ..                          ...        ...      ...
# 195                   Fulham FC  2011/2012      Not
# 196         Blackburn Rovers FC  2011/2012      Not
# 197           Wigan Athletic FC  2011/2012      Not
# 198  Wolverhampton Wanderers FC  2011/2012      Not
# 199         Bolton Wanderers FC  2011/2012      Not
#
# [200 rows x 3 columns]

# %%
past_soccer = soccer_data_df[(soccer_data_df["season"] == "2010/2011") | (soccer_data_df["season"] == "2011/2012") | (soccer_data_df["season"] == "2012/2013") | (soccer_data_df["season"] == "2013/2014") | (soccer_data_df["season"] == "2014/2015") | (soccer_data_df["season"] == "2015/2016") | (soccer_data_df["season"] == "2016/2017") | (soccer_data_df["season"] == "2017/2018")]
past_soccer
# Out:
#                           team_name        common_name     season  country  \
# 60                       Arsenal FC            Arsenal  2017/2018  England
# 61             Tottenham Hotspur FC  Tottenham Hotspur  2017/2018  England
# 62               Manchester City FC    Manchester City  2017/2018  England
# 63                Leicester City FC     Leicester City  2017/2018  England
# 64                    Stoke City FC         Stoke City  2017/2018  England
# ...                             ...                ...        ...      ...
# 1033                    UD Almer??a           Almer??a  2010/2011    Spain
# 1034   Real Club Deportivo Mallorca       RCD Mallorca  2010/2011    Spain
# 1035                  Real Zaragoza      Real Zaragoza  2010/2011    Spain
# 1036  Real Racing Club de Santander   Racing Santander  2010/2011    Spain
# 1037                   H??rcules CF       H??rcules CF  2010/2011    Spain
#
#       matches_played  matches_played_home  matches_played_away  \
# ...

# %%
current_soccer = soccer_data_df[(soccer_data_df["season"] == "2018/2019") | (soccer_data_df["season"] == "2019/2020") | (soccer_data_df["season"] == "2020/2021")]
current_soccer
# Out:
#                             team_name           common_name     season  \
# 0                          Arsenal FC               Arsenal  2020/2021
# 1                Tottenham Hotspur FC     Tottenham Hotspur  2020/2021
# 2                  Manchester City FC       Manchester City  2020/2021
# 3                   Leicester City FC        Leicester City  2020/2021
# 4             West Bromwich Albion FC  West Bromwich Albion  2020/2021
# ...                               ...                   ...        ...
# 1053           Getafe Club de F?§tbol             Getafe CF  2020/2021
# 1054                         Elche CF              Elche CF  2020/2021
# 1055  Real Valladolid Club de F?§tbol       Real Valladolid  2020/2021
# 1056                        SD Huesca             SD Huesca  2020/2021
# 1057                        C?­diz CF                C?­diz  2020/2021
#
#       country  matches_played  matches_played_home  matches_played_away  \
# ...

# %%
# Create our features
X = soccer_data_df.drop("Champion",axis=1)
X = pd.get_dummies(X)

# Create our target
y = soccer_data_df["Champion"]

# %%
X.describe()
# Out:
#        matches_played  matches_played_home  matches_played_away  \
# count     1058.000000          1058.000000          1058.000000
# mean        34.801512            17.400756            17.400756
# std          7.283963             3.645876             3.646135
# min         11.000000             5.000000             5.000000
# 25%         34.000000            17.000000            17.000000
# 50%         38.000000            19.000000            19.000000
# 75%         38.000000            19.000000            19.000000
# max         38.000000            19.000000            19.000000
#
#        suspended_matches         wins    wins_home    wins_away        draws  \
# count        1058.000000  1058.000000  1058.000000  1058.000000  1058.000000
# mean            0.015123    13.007561     7.909263     5.098299     8.786389
# std             0.136721     6.211042     3.680639     3.063160     3.371611
# min             0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# Not         1004
# Champion      54
# Name: Champion, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
rf = BalancedRandomForestClassifier(n_estimators = 100, random_state=1)
rf = rf.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = rf.predict(X_test)
balanced_accuracy_score(y_test, y_pred)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
