# %%
#IMPORT DEPENDENCY
import pandas as pd

# %%
#IMPORT CSV
soccer_data_load = "soccer_data_V1.csv"
soccer_data_df = pd.read_csv(soccer_data_load, encoding = 'unicode_escape')

# %%
soccer_data_df
# Out:
#                             team_name           common_name     season  \
# 0                          Arsenal FC               Arsenal  2020/2021
# 1                Tottenham Hotspur FC     Tottenham Hotspur  2020/2021
# 2                  Manchester City FC       Manchester City  2020/2021
# 3                   Leicester City FC        Leicester City  2020/2021
# 4             West Bromwich Albion FC  West Bromwich Albion  2020/2021
# ...                               ...                   ...        ...
# 1053           Getafe Club de F?§tbol             Getafe CF  2020/2021
# 1054                         Elche CF              Elche CF  2020/2021
# 1055  Real Valladolid Club de F?§tbol       Real Valladolid  2020/2021
# 1056                        SD Huesca             SD Huesca  2020/2021
# 1057                        C?­diz CF                C?­diz  2020/2021
#
#       country  matches_played  matches_played_home  matches_played_away  \
# ...

# %%
for column in soccer_data_df.columns:
    print(f"Column {column} has {soccer_data_df[column].isnull().sum()} null values")
# Out:
# Column team_name has 0 null values
# Column common_name has 0 null values
# Column season has 0 null values
# Column country has 0 null values
# Column matches_played has 0 null values
# Column matches_played_home has 0 null values
# Column matches_played_away has 0 null values
# Column suspended_matches has 0 null values
# Column wins has 0 null values
# Column wins_home has 0 null values
# Column wins_away has 0 null values
# Column draws has 0 null values
# Column draws_home has 0 null values
# Column draws_away has 0 null values
# Column losses has 0 null values
# Column losses_home has 0 null values
# Column losses_away has 0 null values
# Column points_per_game has 0 null values
# Column points_per_game_home has 0 null values
# Column points_per_game_away has 0 null values
# Column league_position has 0 null values
# Column league_position_home has 0 null values
# Column league_position_away has 0 null values
# Column performance_rank has 0 null values
# ...
